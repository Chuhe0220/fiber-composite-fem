# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import axes3d
import sympy as sy
from sympy.solvers import solve

# %%
# Discretization of triangle
# Generate the grid and mash in 2D plane
tolerance = 0.01

lambda1 = np.array([1./3., 1./3.])
lambda5 = np.array([0.5 - 0.5*tolerance, 0.5 - 0.5*tolerance])
lambda15 = [1.0 - 2*tolerance, tolerance]

lambda2 = lambda1 + 0.25 * (lambda5 - lambda1)
lambda3 = lambda1 + 0.50 * (lambda5 - lambda1)
lambda4 = lambda1 + 0.75 * (lambda5 - lambda1)
lambda6 = lambda1 + 0.25 * (lambda15 - lambda1)
lambda9 = lambda5 + 0.25 * (lambda15 - lambda5)
lambda10 = lambda1 + 0.50 * (lambda15 - lambda1)
lambda12 = lambda5 + 0.50 * (lambda15 - lambda5)
lambda13 = lambda1 + 0.75 * (lambda15 - lambda1)
lambda14 = lambda5 + 0.75 * (lambda15 - lambda5)

# Define the intersections of two lines
def line_intersection(line1, line2):
    xdiff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    ydiff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1])

    def det(a, b):
        return a[0] * b[1] - a[1] * b[0]

    div = det(xdiff, ydiff)
    if div == 0:
        raise Exception('lines do not intersect')

    d = (det(*line1), det(*line2))
    x = det(d, xdiff) / div
    y = det(d, ydiff) / div
    return x, y

lambda7 = np.array(line_intersection((lambda2,lambda14),(lambda3,lambda10)))
lambda8 = np.array(line_intersection((lambda4,lambda13),(lambda3,lambda12)))
lambda11 = np.array(line_intersection((lambda2,lambda14),(lambda4,lambda13)))

tri_domain = (lambda5, lambda1, lambda15)

z_points = [0.10, 0.14, 0.18]
difference = z_points[2]-z_points[0]

# Create a dictionary for nodes
nodes = {'lambda1':lambda1,
        'lambda2':lambda2,
        'lambda3':lambda3,
        'lambda4':lambda4,
        'lambda5':lambda5,
        'lambda6':lambda6,
        'lambda7':lambda7,
        'lambda8':lambda8,
        'lambda9':lambda9,
        'lambda10':lambda10,
        'lambda11':lambda11,
        'lambda12':lambda12,
        'lambda13':lambda13,
        'lambda14':lambda14,
        'lambda15':lambda15}

key, coor = zip(*nodes.items())

# %%
# Create and add triangles into a list
triangles=[]

triangles.append((lambda2,lambda1,lambda6))#0
triangles.append((lambda2,lambda6,lambda7))#1#
triangles.append((lambda3,lambda2,lambda7))#2
triangles.append((lambda3,lambda7,lambda8))#3#
triangles.append((lambda4,lambda3,lambda8))#4
triangles.append((lambda4,lambda8,lambda9))#5#
triangles.append((lambda5,lambda4,lambda9))#6
triangles.append((lambda7,lambda6,lambda10))#7
triangles.append((lambda7,lambda10,lambda11))#8#
triangles.append((lambda8,lambda7,lambda11))#9
triangles.append((lambda8,lambda11,lambda12))#10#
triangles.append((lambda9,lambda8,lambda12))#11
triangles.append((lambda11,lambda10,lambda13))#12
triangles.append((lambda11,lambda13,lambda14))#13#
triangles.append((lambda12,lambda11,lambda14))#14
triangles.append((lambda14,lambda13,lambda15))#15

# Two directions of triangle,we generate two sets to save those two directional triangles seperately
TriDirection1 = [triangles[0], triangles[2], triangles[4], triangles[6], triangles[7], triangles[9], triangles[11], triangles[12], triangles[14], triangles[15]]
TriDirection2 = [triangles[1], triangles[3], triangles[5], triangles[8], triangles[10], triangles[13]]

# %%
# Define shape functions for tetrahedral
def ShapeFunction_tetrahedral(p1=[], p2=[], p3=[], p4=[], randomP=[]):
    global x1, x2, x3, x4
    x1 = p1[0]
    x2 = p2[0]
    x3 = p3[0]
    x4 = p4[0]
    global y1, y2, y3, y4
    y1 = p1[1]
    y2 = p2[1]
    y3 = p3[1]
    y4 = p4[1]
    global z1, z2, z3, z4
    z1 = p1[2]
    z2 = p2[2]
    z3 = p3[2]
    z4 = p4[2]
    
    x,y,z = sy.symbols("x,y,z", real=True)
    N1 = 1-x-y-z
    N2 = x
    N3 = y
    N4 = z
    
    lam1_coor = randomP[0]
    lam2_coor = randomP[1]
    z_RanPt = randomP[2]
    
    solution = solve([lam1_coor-(x1*N1+x2*N2+x3*N3+x4*N4), lam2_coor-(y1*N1+y2*N2+y3*N3+y4*N4), z_RanPt-(z1*N1+z2*N2+z3*N3+z4*N4)], 
                    (x, y, z), dict = True)
    key, val = zip(*solution[0].items())
    
    global s1, s2, s3, s4
    s1 = 1-val[0]-val[1]-val[2]
    s2 = val[0]
    s3 = val[1]
    s4 = val[2]
    
    return s1, s2, s3, s4

# %%
# To check a point locate within a triangle or not (including on boundary)
def point_in_triangle(point, triangle):
    """Returns True if the point is inside the triangle
    and returns False if it falls outside.
    - The argument *point* is a tuple with two elements
    containing the X,Y coordinates respectively.
    - The argument *triangle* is a tuple with three elements each
    element consisting of a tuple of X,Y coordinates.

    It works like this:
    Walk clockwise or counterclockwise around the triangle
    and project the point onto the segment we are crossing
    by using the dot product.
    Finally, check that the vector created is on the same side
    for each of the triangle's segments.
    """
    # Unpack arguments
    x, y = point
    ax, ay = triangle[0]
    bx, by = triangle[1]
    cx, cy = triangle[2]
    # Segment A to B
    side_1 = (x - bx) * (ay - by) - (ax - bx) * (y - by)
    # Segment B to C
    side_2 = (x - cx) * (by - cy) - (bx - cx) * (y - cy)
    # Segment C to A
    side_3 = (x - ax) * (cy - ay) - (cx - ax) * (y - ay)
    # All the signs must be positive or all negative
    return (side_1 < 0.0) == (side_2 < 0.0) == (side_3 < 0.0)

def find_key(input_dict, value):
    return {k for k, v in input_dict.items() if np.array_equal(v,value)}

# %%
# To check the point in tetrahedral

# Self-defined method from http://steve.hollasch.net/cgindex/geometry/ptintet.html
def inTetrahedral(V1=[], V2=[], V3=[], V4=[], P=[]):
    D0 = np.linalg.det(np.array([[V1[0], V1[1], V1[2], 1], 
                                 [V2[0], V2[1], V2[2], 1], 
                                 [V3[0], V3[1], V3[2], 1], 
                                 [V4[0], V4[1], V4[2], 1]]))
    
    D1 = np.linalg.det(np.array([[P[0],  P[1],  P[2],  1], 
                                 [V2[0], V2[1], V2[2], 1], 
                                 [V3[0], V3[1], V3[2], 1], 
                                 [V4[0], V4[1], V4[2], 1]]))
    
    D2 = np.linalg.det(np.array([[V1[0], V1[1], V1[2], 1], 
                                 [P[0],  P[1],  P[2],  1], 
                                 [V3[0], V3[1], V3[2], 1], 
                                 [V4[0], V4[1], V4[2], 1]]))
    
    D3 = np.linalg.det(np.array([[V1[0], V1[1], V1[2], 1], 
                                 [V2[0], V2[1], V2[2], 1], 
                                 [P[0],  P[1],  P[2], 1], 
                                 [V4[0], V4[1], V4[2], 1]]))
    
    D4 = np.linalg.det(np.array([[V1[0], V1[1], V1[2], 1], 
                                 [V2[0], V2[1], V2[2], 1], 
                                 [V3[0], V3[1], V3[2], 1], 
                                 [P[0],  P[1],  P[2], 1]]))
    
    if D0>0 and D1>0 and D2>0 and D3>0 and D4>0:
        return True
    else:
        return False

# From https://stackoverflow.com/questions/25179693/how-to-check-whether-the-point-is-in-the-tetrahedron-or-not
def sameside(v1,v2,v3,v4,p):
    normal = np.cross(v2-v1, v3-v1)
    return (np.dot(normal, v4-v1) * np.dot(normal, p-v1) > 0)

# Nico's solution
def pointInside(v1,v2,v3,v4,p):   
    return sameside(v1, v2, v3, v4, p) and sameside(v2, v3, v4, v1, p) and sameside(v3, v4, v1, v2, p) and sameside(v4, v1, v2, v3, p)

# %%
# Verify the orthogonality of matrix R

def check_orthogonal(M):
    # make sure the input is a matrix
    if len(np.shape(M)) != 2:
        print("error: input is not a matrix")
        return False
    # make sure the input is a square matrix
    dim = np.shape(M)[0]
    if dim != np.shape(M)[1]:
        print("error: input is not a square matrix")
        return False
    A = np.dot(M, M.T)
    if np.allclose(A, np.identity(dim)):
        #print("matrix is orthogonal")
        return True
    else:
        #print("matrix is not orthogonal")
        return False

# %%
# Generate matrix A and its eigenvalues as coordinate of the random point

matirces_A = []
matrices_R = []
transpose_R = []

for i in range(0,100):
    
    # Generate random matrix A
    A_random = np.random.rand(3,3)
    A_symmetric = 0.5 * (A_random + np.transpose(A_random))
    w,R = np.linalg.eig(A_symmetric)
    Rt  = np.transpose(R)
    w   = w.clip(min=0.01)
    w  /= np.linalg.norm(w, 1)
    wDiagonal = np.diag(w)

    A_positiveDefinite = np.real(np.dot(np.dot(R, wDiagonal), Rt))
    
    # Compute eigenvalues and eigenvectors of A
    evalue, evect = np.linalg.eig(A_positiveDefinite)
    evalue1 = np.sort(evalue)[::-1]
    EV_coor = [evalue1[0], evalue1[1]]
    
    # Check the random point located within triangle && all of entries in matrix A is positive  
    if check_orthogonal(R):
        if point_in_triangle(EV_coor, tri_domain):
            matirces_A.append(A_positiveDefinite)
            matrices_R.append(R)
            transpose_R.append(Rt)
        
# Use first matrix from list matirces_A for plotting and computation
evalue2, evect2 = np.linalg.eig(matirces_A[0])
evalue3 = np.sort(evalue2)[::-1]
random_point_new = [evalue3[0], evalue3[1]]
random_point_new_3d = [evalue3[0], evalue3[1], random.uniform(z_points[0], z_points[2])]

print('The fiber orientation tensor A is:')
print(matirces_A[0])
print('The eigenvalue of matrix A is: ',evalue2)
print('')

print('The matrix R is:')
print(matrices_R[0])
print('The orthogonality of matrix R: ',check_orthogonal(matrices_R[0]))
print('')

print('The transpose of matrix R is:')
print(transpose_R[0])
print('')

print('Generated random point is:')
print(random_point_new_3d)
print('')
# Out:
# The fiber orientation tensor A is:
# [[0.27657658 0.17080001 0.25096023]
#  [0.17080001 0.35807901 0.08285744]
#  [0.25096023 0.08285744 0.36534441]]
# The eigenvalue of matrix A is:  [0.67391858 0.04283466 0.28324676]
#
# The matrix R is:
# [[ 0.60617986  0.79048142  0.08766476]
#  [ 0.4917871  -0.28591822 -0.82243311]
#  [ 0.62505314 -0.54165478  0.56206643]]
# The orthogonality of matrix R:  True
#
# The transpose of matrix R is:
# [[ 0.60617986  0.4917871   0.62505314]
#  [ 0.79048142 -0.28591822 -0.54165478]
#  [ 0.08766476 -0.82243311  0.56206643]]
#
# Generated random point is:
# [0.6739185812938507, 0.28324675621029216, 0.13917557577367798]

# %%
# Find the nearest triangle for random point

print('We found the random node in following triangle: ')
triangle_nodes = []

for coordinate in coor:
    for triangle in triangles:
        if point_in_triangle(random_point_new, triangle):
            for j in range(3):
                if np.array_equal(coordinate, triangle[j]):
                    print(find_key(nodes, triangle[j]))
                    print(triangle[j])
                    triangle_nodes.append(triangle[j])
                    
triangle_nodes = tuple(triangle_nodes)

result = [1]
for i in TriDirection2: 
    if np.array_equal(i, triangle_nodes):
        result.append(2)
        
if len(result) == 1:
    triangle_nodes = list(triangle_nodes)
    node1=triangle_nodes[1]
    node2=triangle_nodes[0] 
    node3=triangle_nodes[2]
    triangle_nodes.clear()
    triangle_nodes.append(node1)
    triangle_nodes.append(node2)
    triangle_nodes.append(node3)
    
print(triangle_nodes)
# Out:
# We found the random node in following triangle:
# {'lambda8'}
# [0.57583333 0.33333333]
# {'lambda11'}
# [0.69708333 0.21208333]
# {'lambda12'}
# [0.7375 0.2525]
# (array([0.57583333, 0.33333333]), array([0.69708333, 0.21208333]), array([0.7375, 0.2525]))

# %%
# Define and change the number of layers

layers = int(2)
print('We have now '+str(layers)+' layer(s):')

layers_list = []

for i in range(0, layers):
    layers_list.append((i*(difference/layers)+z_points[0], (i+1)*(difference/layers)+z_points[0]))
    print('The layer {0} from'.format(i+1), layers_list[i])
    
for start, stop in layers_list:
    if start <= random_point_new_3d[2] <= stop:
        located_layer = (start, stop)
        for pair in layers_list:
            if located_layer == pair:
                global index
                index = layers_list.index(pair)
                print('We found the random point in layer '+str(index+1))
# Out:
# We have now 2 layer(s):
# The layer 1 from (0.1, 0.14)
# The layer 2 from (0.14, 0.18)
# We found the random point in layer 1

# %%
# Find the nearest prism for random point

prism_nodes = []

# to add nodes in different layer, layer by layer
if len(result) == 2:
    for i in range(len(triangle_nodes)):
        prism_node_1 = np.append(triangle_nodes[i], layers_list[index][0])
        prism_nodes.append(prism_node_1)
    for j in range(len(triangle_nodes)):
        prism_node_2 = np.append(triangle_nodes[j], layers_list[index][1])
        prism_nodes.append(prism_node_2)
elif len(result) == 1:
    for i in [1,0,2]:
        prism_node_1 = np.append(triangle_nodes[i], layers_list[index][0])
        prism_nodes.append(prism_node_1)
    for j in [1,0,2]:
        prism_node_2 = np.append(triangle_nodes[j], layers_list[index][1])
        prism_nodes.append(prism_node_2)
    
print(prism_nodes)
# Out:
# [array([0.57583333, 0.33333333, 0.1       ]), array([0.69708333, 0.21208333, 0.1       ]), array([0.7375, 0.2525, 0.1   ]), array([0.57583333, 0.33333333, 0.14      ]), array([0.69708333, 0.21208333, 0.14      ]), array([0.7375, 0.2525, 0.14  ])]

# %%
# Construct three tetrahedrals within prism

tet1 = [[prism_nodes[5], prism_nodes[4], prism_nodes[3], prism_nodes[2]], 
        [prism_nodes[3], prism_nodes[1], prism_nodes[0], prism_nodes[2]],
        [prism_nodes[4], prism_nodes[1], prism_nodes[3], prism_nodes[2]]]

tet2 = [[prism_nodes[3], prism_nodes[0], prism_nodes[4], prism_nodes[5]],
        [prism_nodes[4], prism_nodes[5], prism_nodes[0], prism_nodes[1]],
        [prism_nodes[5], prism_nodes[2], prism_nodes[0], prism_nodes[1]]]

# Check the nearest tetrahedral for random point
tetrahedral_nodes = []
if len(result) == 1:
    for i in tet1:
        if inTetrahedral(i[0], i[1], i[2], i[3], random_point_new_3d): #and pointInside(i[0], i[1], i[2], i[3], random_point_new_3d):
            print('The random point locates in triangle direction 1, and the four nodes of tetrahedral:')
            print(i)
            tetrahedral_nodes.append(i)
elif len(result) == 2:
    for j in tet2:
        if inTetrahedral(j[0], j[1], j[2], j[3], random_point_new_3d): #and pointInside(j[0], j[1], j[2], j[3], random_point_new_3d):
            print('The random point locates in triangle direction 2, and the four nodes of tetrahedral:')
            print(j)
            tetrahedral_nodes.append(j)
# Out:
# The random point locates in triangle direction 2, and the four nodes of tetrahedral:
# [array([0.57583333, 0.33333333, 0.14      ]), array([0.57583333, 0.33333333, 0.1       ]), array([0.69708333, 0.21208333, 0.14      ]), array([0.7375, 0.2525, 0.14  ])]

# %%
print('Values of s1, s2 ,s3 and s4: ')
print(ShapeFunction_tetrahedral(tetrahedral_nodes[0][0], tetrahedral_nodes[0][1], tetrahedral_nodes[0][2], tetrahedral_nodes[0][3], random_point_new_3d))

x_ran = x1*s1+x2*s2+x3*s3+x4*s4
y_ran = y1*s1+y2*s2+y3*s3+y4*s4
z_ran = z1*s1+z2*s2+z3*s3+z4*s4
# Out:
# Values of s1, s2 ,s3 and s4:
# (0.368371558945831, 0.0172198456541442, 0.593797989741974, 0.0206106056580509)

# %%
# Generate points 

x_points = []
y_points = []

for i in range(0,len(coor)):
    x_points.append(coor[i][0])
    y_points.append(coor[i][1])
    
x_points = np.array(x_points)
y_points = np.array(y_points)
z1 = np.full(shape=len(x_points), fill_value=z_points[0])
z2 = np.full(shape=len(x_points), fill_value=z_points[2])

fig_3d = plt.figure()
ax_3d = plt.axes(projection='3d')
ax_3d.scatter3D(x_points, y_points, z1, s=3)
ax_3d.scatter3D(x_points, y_points, z2, s=3)
#ax_3d.view_init(60, 35)

# Plot generated random point in 3D
ax_3d.scatter3D(random_point_new_3d[0], random_point_new_3d[1], random_point_new_3d[2], color='r', label='random point', s=1.5)
ax_3d.scatter3D(x_ran, y_ran, z_ran, color='b', label='random point by shape function', s=.5)

# Annotate 2D grid
ax_3d.text(lambda1[0],lambda1[1], z_points[0], "1", color='red',size=4)
ax_3d.text(lambda2[0],lambda2[1], z_points[0], "2", color='red',size=4)
ax_3d.text(lambda3[0],lambda3[1], z_points[0], "3", color='red',size=4)
ax_3d.text(lambda4[0],lambda4[1], z_points[0], "4", color='red',size=4)
ax_3d.text(lambda5[0],lambda5[1], z_points[0], "5", color='red',size=4)
ax_3d.text(lambda6[0],lambda6[1], z_points[0], "6", color='red',size=4)
ax_3d.text(lambda7[0],lambda7[1], z_points[0], "7", color='red',size=4)
ax_3d.text(lambda8[0],lambda8[1], z_points[0], "8", color='red',size=4)
ax_3d.text(lambda9[0],lambda9[1], z_points[0], "9", color='red',size=4)
ax_3d.text(lambda10[0],lambda10[1], z_points[0], "10", color='red',size=4)
ax_3d.text(lambda11[0],lambda11[1], z_points[0], "11", color='red',size=4)
ax_3d.text(lambda12[0],lambda12[1], z_points[0], "12", color='red',size=4)
ax_3d.text(lambda13[0],lambda13[1], z_points[0], "13", color='red',size=4)
ax_3d.text(lambda14[0],lambda14[1], z_points[0], "14", color='red',size=4)
ax_3d.text(lambda15[0],lambda15[1], z_points[0], "15", color='red',size=4, horizontalalignment='right')

# Annotate three layers
ax_3d.text(lambda15[0]+0.01,lambda15[1]+0.01, z_points[0], '''z'=10%''', color='purple',size=5, weight='bold')
ax_3d.text(lambda15[0]+0.01,lambda15[1]+0.01, z_points[1], '''z'=14%''', color='purple',size=5, weight='bold')
ax_3d.text(lambda15[0]+0.01,lambda15[1]+0.01, z_points[2], '''z'=18%''', color='purple',size=5, weight='bold')

# Generate lines
ax_3d.plot([lambda1[0], lambda15[0]], [lambda1[1], lambda15[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'solid')
ax_3d.plot([lambda2[0], lambda14[0]], [lambda2[1], lambda14[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda3[0], lambda12[0]], [lambda3[1], lambda12[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda4[0], lambda9[0]], [lambda4[1], lambda9[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda1[0], lambda5[0]], [lambda1[1], lambda5[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'solid')
ax_3d.plot([lambda6[0], lambda9[0]], [lambda6[1], lambda9[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda10[0], lambda12[0]], [lambda10[1], lambda12[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda13[0], lambda14[0]], [lambda13[1], lambda14[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda2[0], lambda6[0]], [lambda2[1], lambda6[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda3[0], lambda10[0]], [lambda3[1], lambda10[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda4[0], lambda13[0]], [lambda4[1], lambda13[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda5[0], lambda15[0]], [lambda5[1], lambda15[1]], z_points[0], color = 'b', linewidth = 0.2, linestyle = 'solid')

ax_3d.plot([lambda1[0], lambda15[0]], [lambda1[1], lambda15[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'solid')
ax_3d.plot([lambda2[0], lambda14[0]], [lambda2[1], lambda14[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda3[0], lambda12[0]], [lambda3[1], lambda12[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda4[0], lambda9[0]], [lambda4[1], lambda9[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda1[0], lambda5[0]], [lambda1[1], lambda5[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'solid')
ax_3d.plot([lambda6[0], lambda9[0]], [lambda6[1], lambda9[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda10[0], lambda12[0]], [lambda10[1], lambda12[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda13[0], lambda14[0]], [lambda13[1], lambda14[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda2[0], lambda6[0]], [lambda2[1], lambda6[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda3[0], lambda10[0]], [lambda3[1], lambda10[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda4[0], lambda13[0]], [lambda4[1], lambda13[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'dashed')
ax_3d.plot([lambda5[0], lambda15[0]], [lambda5[1], lambda15[1]], z_points[2], color = 'b', linewidth = 0.2, linestyle = 'solid')

# Plot different layers
for i in range(1,layers):
    ax_3d.plot([lambda1[0], lambda15[0]], [lambda1[1], lambda15[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'solid')
    ax_3d.plot([lambda2[0], lambda14[0]], [lambda2[1], lambda14[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda3[0], lambda12[0]], [lambda3[1], lambda12[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda4[0], lambda9[0]], [lambda4[1], lambda9[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda1[0], lambda5[0]], [lambda1[1], lambda5[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'solid')
    ax_3d.plot([lambda6[0], lambda9[0]], [lambda6[1], lambda9[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda10[0], lambda12[0]], [lambda10[1], lambda12[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda13[0], lambda14[0]], [lambda13[1], lambda14[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda2[0], lambda6[0]], [lambda2[1], lambda6[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda3[0], lambda10[0]], [lambda3[1], lambda10[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda4[0], lambda13[0]], [lambda4[1], lambda13[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'dashed')
    ax_3d.plot([lambda5[0], lambda15[0]], [lambda5[1], lambda15[1]], i*(difference/layers)+z_points[0], color = 'b', linewidth = 0.2, linestyle = 'solid')

# Divide prisms into three tetrahedrals
for i in TriDirection1:
    ax_3d.plot([i[0][0], i[2][0]], [i[0][1], i[2][1]], [z_points[1], z_points[0]], color='g', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([i[0][0], i[2][0]], [i[0][1], i[2][1]], [z_points[2], z_points[1]], color='g', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([i[1][0], i[2][0]], [i[1][1], i[2][1]], [z_points[1], z_points[0]], color='g', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([i[1][0], i[2][0]], [i[1][1], i[2][1]], [z_points[2], z_points[1]], color='g', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([i[0][0], i[1][0]], [i[0][1], i[1][1]], [z_points[0], z_points[1]], color='g', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([i[0][0], i[1][0]], [i[0][1], i[1][1]], [z_points[1], z_points[2]], color='g', linewidth = '0.1', linestyle = 'solid')
for j in  TriDirection2:  
    ax_3d.plot([j[0][0], j[1][0]], [j[0][1], j[1][1]], [z_points[0], z_points[1]], color='m', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([j[0][0], j[1][0]], [j[0][1], j[1][1]], [z_points[1], z_points[2]], color='m', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([j[0][0], j[2][0]], [j[0][1], j[2][1]], [z_points[0], z_points[1]], color='m', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([j[0][0], j[2][0]], [j[0][1], j[2][1]], [z_points[1], z_points[2]], color='m', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([j[1][0], j[2][0]], [j[1][1], j[2][1]], [z_points[0], z_points[1]], color='m', linewidth = '0.1', linestyle = 'solid')
    ax_3d.plot([j[1][0], j[2][0]], [j[1][1], j[2][1]], [z_points[1], z_points[2]], color='m', linewidth = '0.1', linestyle = 'solid')
    
    
# Connection of upper and bottom planes
from_pts = []
for ea in np.stack((x_points, y_points, z1), axis=-1):
    from_pts.append(ea)

dest_pts = []
for ea2 in np.stack((x_points, y_points, z2), axis=-1):
    dest_pts.append(ea2)
    
for from_to in zip(from_pts, dest_pts):
    ax_3d.plot([from_to[0][0],from_to[1][0]], 
               [from_to[0][1],from_to[1][1]], 
               [from_to[0][2],from_to[1][2]], "b", linewidth=0.2)
    
subscript = str.maketrans("0123456789", "₀₁₂₃₄₅₆₇₈₉")
ax_3d.set_xlabel('λ1'.translate(subscript), fontsize=12)
ax_3d.set_ylabel('λ2'.translate(subscript), fontsize=12)
ax_3d.set_zlabel('fiber volume fraction v (%)', fontsize=8)
ax_3d.set_xlim3d(0.3,1)
ax_3d.set_ylim3d(0,0.7)
ax_3d.set_zlim3d(z_points[0],z_points[2]+0.01)
ax_3d.legend(loc=0, bbox_to_anchor=(1.05, 1),fontsize=7)

# set z ticks
labels = [item.get_text() for item in ax_3d.get_zticklabels()]
labels[0] = '10%'
labels[2] = '14%'
labels[4] = '18%'
ax_3d.set_zticklabels(labels)

ax_3d.set_title('3D shape function and unit triangulation prism')

fig_3d.savefig('StandardTetrahedral_3D (10%-18%).pdf', format='pdf', bbox_inches='tight')
# Out:
# <ipython-input-140-c01d30ff0ddf>:134: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_3d.set_zticklabels(labels)
